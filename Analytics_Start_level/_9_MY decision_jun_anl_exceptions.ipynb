# %% [markdown]
# # Исключения
# ## Домашняя работа

# %% [markdown]
# ### Вопросы по лекциям.

# %% [markdown]
# Как поймать вообще все ошибки, которые могут произойти?

# %% [markdown]
# **Ответ:**
# Указать в качестве extpt-а сообщение "Exeption"

# %% [markdown]
# Сколько раз подряд можно указывать except?

# %% [markdown]
# **Ответ:**
# Столько, сколько нужно поймать исключений (если ловится конктретно исключение, а не все сразу)

# %% [markdown]
# Вы хотите с помощью print вывести название ошибки в консоль, как это сделать?

# %% [markdown]
# **Ответ:**
# В принт записать название / код данной ошибки.

# %% [markdown]
# Вы хотите с помощью print вывести параметры ошибки в консоль, как это сделать?

# %% [markdown]
# **Ответ:**
# Написать после указания типа ошибки фразу "as exp" (название может быть любым, важно "as"), и потом его уже вывести в принте

# %% [markdown]
# Что такое DeprecationWarning?

# %% [markdown]
# **Ответ:**
# Предупреждение о выходе новой версии. О том, что в новой версии данная функция станет не валидной.

# %% [markdown]
# ### Разминочные задания.
# <br>
#
# Вам даны две функции. Поисследуйте, какие ошибки могут возникнуть при их реализации. Обработайте эти ошибки.

# %%
def div():
    for i in range(2):
        x = int(input("enter a number: "))
        y = int(input("enter another number: "))
        print(x, '/', y, '=', x/y)

# %%
def sumOfPairs(L1, L2):
    sum = 0
    sumOfPairs = []
    for i in range(len(L1)):
        sumOfPairs.append(L1[i]+L2[i])

    print("sumOfPairs = ", sumOfPairs)

# %% [markdown]
# ### Задание 1.
#
# Есть файл с протоколом регистраций пользователей на сайте (registrations.txt).<br>
# Каждая строка содержит информацию о имени, электронной почте и возрасте человека. <br><br>
#
#
# Надо проверить данные из файла, для каждой строки:
#  - присутсвуют все три поля
#  - поле имени содержит только буквы
#  - поле email содержит @ и .
#  - поле возраст является числом от 10 до 99<br>
#
# В результате проверки нужно сформировать два файла
#  - registrations_good.log для правильных данных, записывать строки как есть
# - registrations_bad.log для ошибочных, записывать строку и вид ошибки.<br>
#
# Для валидации строки данных написать метод, который может выкидывать исключения:
#  - НЕ присутсвуют все три поля: ValueError
#  - поле имени содержит НЕ только буквы: NotNameError (кастомное исключение)
#  - поле email НЕ содержит @ и .(точку): NotEmailError (кастомное исключение)
#  - поле возраст НЕ является числом от 10 до 99: ValueError
# Вызов метода обернуть в try-except.

# %%
### YOUR CODE HERE ###
import re

class NotNameError(Exception):
    def __init__(self, message):
        super().__init__(message)
        
    def __str__(self):
        return "NotNameError"

class NotEmailError(Exception):
    def __init__(self, message):
        super().__init__(message)
        
    def __str__(self):
        return "NotEmailError"

def is_line_validation(line):
    words = line.split(' ')
       
    len_words = len(words)
    if len_words < 3:
        raise ValueError('НЕ присутсвуют все три поля')
    elif (len_words > 3):
        raise ValueError('Присутствует больше 3 полей')
    else:
        name, email, age = words[0], words[1], words[2]
    
    if (re.search(r'[^a-zA-Z а-яА-ЯёЁ]', name)):
        raise NotNameError('поле имени содержит НЕ только буквы')
    
    if email.find("@") == -1:
        raise NotEmailError('поле email НЕ содержит @')
    elif email.find(".") == -1:
        raise NotEmailError('поле email НЕ содержит .(точку)')
    
    if not age.isdigit():
        raise ValueError('поле возраст НЕ является числом')
    elif int(age) < 10 or int(age) > 99:
        raise ValueError('поле возраст НЕ является числом от 10 до 99')
    
    return True

# %%
# тестовая проверка функций с ошибками

line_1 = "Alica test@mail.ru 12"
line_2 = "Alica test@mail.ru"
line_3 = "Alica test@mail.ru 12 2"
line_4 = "Alica1 test@mail.ru 12"
line_5 = "Alica testmail.ru 12"
line_6 = "Alica test@mailru 12"
line_7 = "Alica test@mail.ru 12s"
line_8 = "Alica test@mail.ru 1"
line_9 = "Alica test@mail.ru 120"
line_10 = "Alica test@mail.ru 12.1"
is_line_validation(line_1)
# Out:
# True

# %%
lines_good = []
lines_bad = []

with open('registrations_.txt', mode="r", encoding="utf-8") as ff:
    for line in ff:
        line = line[:-1]
        try:
            if is_line_validation(line):
                lines_good.append(line)
        except ValueError as exc:
            lines_bad.append(line + f" | ValueError {exc.args}")
        except (NotNameError, NotEmailError) as exc:
            lines_bad.append(line + f" | {exc} {exc.args}")
        except Erorr:
            lines_bad.append(line + " | Ошибка не определена")
    
with open('registrations_good.log', mode="w", encoding="utf-8") as ff_good:
    ff_good.write('\n'.join(lines_good))
with open('registrations_bad.log', mode="w", encoding="utf-8") as ff_bad:
    ff_bad.write('\n'.join(lines_bad))

# %%
lines_good
# Out:
# ['Ольга rin@mail.ru 45',
#  'Артём knkjmbwwe@gmail.com 40',
#  'Нагиев kptvmbjlrs@gmail.com 81',
#  'Пенг zrlddzogc@mail.ru 20',
#  'Сянцзян swnjvpt@gmail.com 49',
#  'Степан omsgoxfhv@ya.ru 69',
#  'Владимир opsr@gmail.com 45',
#  'Ван mrv@gmail.com 82',
#  'Чонгкун pkz@mail.ru 18',
#  'Равшан nryx@ya.ru 84',
#  'Волочкова hynhkchl@mail.ru 93',
#  'Артём ezgwiw@mail.ru 70',
#  'Нагиев lvyqdp@mail.ru 19',
#  'Владимир qombe@mail.ru 69',
#  'Ольга vg@ya.ru 12',
#  'Ярослав lczvxi@gmail.com 97',
#  'Дмитрий ruqeueozze@gmail.com 13',
#  'Ольга zl@gmail.com 16',
#  'Мария egod@gmail.com 68',
#  'Ван np@gmail.com 82',
#  'Джигурда himiyb@mail.ru 61',
#  'Чонгкун rggnlsaeeo@mail.ru 71',
#  'Геннадий yhkbfc@gmail.com 32',
#  'Равшан cxmu@mail.ru 11',
#  'Ольга dih@gmail.com 72',
#  'Земфира cju@ya.ru 81',
#  'Нагиев jrb@gmail.com 22',
#  'Равшан ae@mail.ru 48',
#  'Степан no@mail.ru 73',
#  'Чехова sqrzmr@gmail.com 93',
#  'Дмитрий vtnk@ya.ru 78',
#  'Джамшут sj@gmail.com 48',
# ...

# %%
lines_bad
# Out:
# ["Пенг42 euxtjquwo@mail.ru 32 | NotNameError ('поле имени содержит НЕ только буквы',)",
#  "Пенг grnsf.mail.ru 70 | NotEmailError ('поле email НЕ содержит @',)",
#  "Владимир 8 gumxfigvam | NotEmailError ('поле email НЕ содержит @',)",
#  "Джамшут tyyolvkn@ya.ru 7 | ValueError ('поле возраст НЕ является числом от 10 до 99',)",
#  "Дмитрий sdw@gmail.com 101 | ValueError ('поле возраст НЕ является числом от 10 до 99',)",
#  "Ольга kbzjth 13 | NotEmailError ('поле email НЕ содержит @',)",
#  "Джигурда arlmdlrn@mail.ru 7 | ValueError ('поле возраст НЕ является числом от 10 до 99',)",
#  "Волочкова tgnrnmo@mail.ru 9 | ValueError ('поле возраст НЕ является числом от 10 до 99',)",
#  "Чонгкун iflyyvp.ru 73 | NotEmailError ('поле email НЕ содержит @',)",
#  "Ярослав42 ffcbzt@gmail.com 74 | NotNameError ('поле имени содержит НЕ только буквы',)",
#  "Яочуан xi@mail.ru 100 | ValueError ('поле возраст НЕ является числом от 10 до 99',)",
# ...
