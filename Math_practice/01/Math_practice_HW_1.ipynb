# %%
from sympy import *

# %%
init_printing(use_unicode=False, wrap_line=False, no_global=True)

# %% [markdown]
# ![2023-01-30_21-43-59.png](attachment:2023-01-30_21-43-59.png)

# %%
x = Symbol('x')
y = Symbol('y')
a = Symbol('a')
b = Symbol('b')
c = Symbol('c')
k = Symbol('k')

# %%
# задание 1
expression_1 = (2*x+3*y)**2 - 3*x*(x*4/3 + 4*y)
expression_1
# Out:
#       /4*x      \              2
# - 3*x*|--- + 4*y| + (2*x + 3*y)
#       \ 3       /

# %%
simplify(expression_1)
# Out:
#    2
# 9*y

# %%
# задание 2
expression_2 = 28*a*b + (2*a - 7*b)**2
expression_2
# Out:
#                     2
# 28*a*b + (2*a - 7*b)

# %%
simplify(expression_2)
# Out:
#    2       2
# 4*a  + 49*b

# %%
# задание 3 (хммм, не получилось сохранить выражение)
expression_3 = (a/2 + a/5) * (1 / ((a)**2))
expression_3
# Out:
#  7
# ----
# 10*a

# %%
simplify(expression_3)
# Out:
#  7
# ----
# 10*a

# %%
# задание 4
expression_4 = (x - 6*x / (x+2)) / ((x-4)/(x+2))
expression_4
# Out:
#         /     6*x \
# (x + 2)*|x - -----|
#         \    x + 2/
# -------------------
#        x - 4

# %%
simplify(expression_4)
# Out:
# x

# %%
# задание 5
expression_5 = (4/a**2 + 9/b**2) * (a*b)**2
expression_5
# Out:
#  2  2 /9    4 \
# a *b *|-- + --|
#       | 2    2|
#       \b    a /

# %%
simplify(expression_5)
# Out:
#    2      2
# 9*a  + 4*b

# %%
# задание 6 (хммм, не получилось сохранить выражение)
expression_6 = 5/(c * k**2) * k**3 * c-(10*k+1)/2
expression_6
# Out:
# -1/2

# %%
simplify(expression_6)
# Out:
# -1/2

# %%
# задание 7
expression_7 = (3*x**2 + 4*x)/(x**2 - 2*x) - (2*x+7)/x - (x+8)/(x-2)
expression_7
# Out:
#    2
# 3*x  + 4*x   x + 8   2*x + 7
# ---------- - ----- - -------
#   2          x - 2      x
#  x  - 2*x

# %%
simplify(expression_7)
# Out:
# -7
# ---
#  x
